# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('dados/bmw.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
df.groupby(['model', 'transmission']).price.describe().sort_values('mean', ascending=False)
# Out:
#                          count          mean           std      min       25%  \
# model     transmission
#  X7       Semi-Auto       38.0  70446.210526   5205.198836  61875.0  65287.50
#           Automatic       17.0  68493.882353   4731.065616  59988.0  65520.00
#  8 Series Semi-Auto       31.0  64043.387097   8910.734117  51980.0  58970.00
#           Automatic        8.0  63821.125000   5855.505283  55980.0  59747.50
#  M5       Semi-Auto       16.0  58582.750000  19359.353951  24310.0  53366.75
#  i8       Automatic       17.0  57012.588235  11135.665321  37995.0  48898.00
#  M5       Automatic       13.0  56747.384615  20199.564614  23490.0  35995.00
#  X5       Semi-Auto      166.0  51116.174699   5079.358008  41211.0  47485.00
#  M4       Automatic       30.0  47054.233333  14072.146700  26499.0  39962.50
#  M2       Manual           1.0  46000.000000           NaN  46000.0  46000.00
#  X6       Semi-Auto       76.0  45710.342105  14936.223387  15380.0  32598.75
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.write_html('first_figure.html', auto_open=True)

# %%
import plotly.express as px
import pandas as pd
# df = px.data.gapminder().query("year == 2007")
df = pd.read_csv('https://raw.githubusercontent.com/ronaldolagepessoa/data_science/master/dados/housing_ok.csv')
fig = px.density_mapbox(df, lat='latitude', lon='longitude', z='preco', radius=10,
                        center=dict(lat=0, lon=180), zoom=0,
                        mapbox_style="stamen-terrain")
fig.write_html('first_figure.html', auto_open=True)
